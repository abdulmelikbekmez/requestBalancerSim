# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cikti.csv")
df
# Out:
#             weight  client id  total waiting time  duration  total request  \
# 0     0.000000e+00          2                   0  2.719820            999
# 1     2.479536e-09          2                   2  3.364190            998
# 2     4.032053e-09          2                   3  1.993064            997
# 3     7.991846e-10          2                   3  4.870586            996
# 4     1.232694e-09          2                   3  2.706245            995
# ...            ...        ...                 ...       ...            ...
# 1993  3.028580e-02          1               31869  4.854091              6
# 1994  4.394498e-02          1               32436  4.965772              5
# 1995  6.799600e-02          1               30977  4.674261              4
# 1996  1.150382e-01          1               30956  4.669405              3
# 1997  2.127257e-01          1               31260  4.894316              2
#
#       priority  completed jobs
# 0            1               2
# ...

# %%
df[df["client id"] == 2]
# Out:
#             weight  client id  total waiting time  duration  total request  \
# 0     0.000000e+00          2                   0  2.719820            999
# 1     2.479536e-09          2                   2  3.364190            998
# 2     4.032053e-09          2                   3  1.993064            997
# 3     7.991846e-10          2                   3  4.870586            996
# 4     1.232694e-09          2                   3  2.706245            995
# ...            ...        ...                 ...       ...            ...
# 1062  9.556805e-03          2                2339  4.764758              4
# 1063  1.558602e-02          2                1956  3.868701              3
# 1064  3.026146e-02          2                2017  4.014367              2
# 1065  7.039485e-02          2                2018  4.142157              1
# 1066  2.618863e-01          2                2239  4.843897              0
#
#       priority  completed jobs
# 0            1               2
# ...

# %%
c1 = df[df["client id"] == 1]
c2 = df[df["client id"] == 2]
c1
# Out:
#             weight  client id  total waiting time  duration  total request  \
# 11    2.090645e-09          1                  44  0.007055            999
# 37    2.732180e-09          1                 470  0.339194            998
# 49    1.186912e-08          1                 201  0.023376            997
# 60    1.623574e-08          1                 723  0.141561            996
# 85    1.860869e-08          1                 156  0.009873            995
# ...            ...        ...                 ...       ...            ...
# 1993  3.028580e-02          1               31869  4.854091              6
# 1994  4.394498e-02          1               32436  4.965772              5
# 1995  6.799600e-02          1               30977  4.674261              4
# 1996  1.150382e-01          1               30956  4.669405              3
# 1997  2.127257e-01          1               31260  4.894316              2
#
#       priority  completed jobs
# 11           2           10001
# ...

# %%
plt.plot(c1["duration"],c1["total waiting time"],"r--", c2["duration"], c2["total waiting time"], "bs")
